# %%
"""Util functions"""

import re
import json

def write_json_to_file(file_path, data):
    with open(file_path, 'w') as f:
        json.dump(data, f, indent=4, sort_keys=True)
        
def load_json_from_file(file_path):
    with open(file_path) as json_file:
        return json.load(json_file)

def first_matching(iterable, predicate):
    return next(x for x in iterable if predicate(x))

def get_file_ext(file_name):
    return file_name.rsplit('.', 1)[-1]

def filter_dict_keys(orig_dict, keys_to_keep):
    return { key: orig_dict[key] for key in keys_to_keep }

def formatted_ms(total_ms, format_str='{min}:{sec}:{ms}'):
    if not type(total_ms) == int:
        return None
    time = total_ms
    ms = int(time % 1000)
    ms_str = '{0:03d}'.format(ms)
    time -= ms
    time /= 1000
    seconds = int(time % 60)
    seconds_str = '{0:02d}'.format(seconds)
    time -= seconds
    time /= 60
    minutes = int(time)
    minutes_str = '{0:02d}'.format(minutes)
    return format_str.format(**{'min': minutes_str, 'sec': seconds_str, 'ms': ms_str})

def dot_formatted_ms(total_ms):
    return formatted_ms(total_ms, '{min}.{sec}.{ms}')

def colon_formatted_ms(total_ms):
    return formatted_ms(total_ms, '{min}:{sec}:{ms}')

def multi_replacer(*key_values):
    replace_dict = dict(key_values)
    replacement_function = lambda match: replace_dict[match.group(0)]
    pattern = re.compile("|".join([re.escape(k) for k, v in key_values]), re.M)
    return lambda string: pattern.sub(replacement_function, string)

def multi_replace(string, *key_values):
    return multi_replacer(*key_values)(string)

def create_file_path(*file_path_parts):
    file_path = ''
    if file_path_parts[0][0] == '/':
        file_path = '/'
    for part in file_path_parts[:-1]:
        file_path += part.strip('/') + '/'
    file_path += file_path_parts[-1]
    return file_path
   
# replacements = ('[', '[[]'), (']', '[]]')
# multi_replace('Runaway [Explicit]', *replacements)
# SHELL_ESCAPE_CHARS = ['[', ']', '?', '!']
# multi_replace('Runaway [Explicit]', *tuple((ch, '[{}]'.format(ch)) for ch in SHELL_ESCAPE_CHARS))

# %%
"""SQLite helper functions"""

import sqlite3

def dict_factory(cursor, row):
    d = {}
    for idx, col in enumerate(cursor.description):
        d[col[0]] = row[idx]
    return d

def get_cursor(db_file):
    conn = sqlite3.connect(db_file)
    conn.row_factory = dict_factory
    return conn.cursor()

def get_itunes_cursor():
    return get_cursor('itunes.db')

def get_mb_cursor():
    return get_cursor('musicbee.db')

def db_info(db_file):
    cursor = get_cursor(db_file)
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    return cursor.fetchall()

def column_names(cursor, table_name):
    return sorted(list(cursor.execute("SELECT * FROM {}".format(table_name)).fetchone().keys()))

def escape_query_value(value):
    return value.replace("'", "''")

# %%
"""
Utils to work with example tracks
"""

track_search_map = {
    'Beck': 'Debra',
    'Kanye West': 'Runaway',
    'Outkast': 'The Way You Move',
    'Chromeo': 'Opening Up (- Ce soir on danse',
}

def get_example_tracks():
    c = get_cursor('itunes.db')
    clause = " OR ".join([
        "(artist='{}' AND name LIKE '%{}%')".format(artist, track_name)
            for artist, track_name in track_search_map.items()
        ])
    q = "SELECT * FROM tracks WHERE {}".format(clause)
    tracks = c.execute(q).fetchall()
    if len(tracks) != len(track_search_map.keys()):
        raise Exception('Found too many or too few tracks')
    return tracks

# [(track['artist'], track['name'], ms_to_min_sec_ms(track['stop_time']))
#     for track in tracks]
# track_debra = first_matching(tracks, lambda t: t['artist'] == 'Beck')
# (ms_to_min_sec_ms(track_debra['start_time']), ms_to_min_sec_ms(track_debra['stop_time']))

# %%
"""File searching utility functions"""

import os
from fnmatch import fnmatch
import subprocess

ORIG_FILE_PATH = '/home/gavin/Music/chop'
CHOPPED_REL_FILE_PATH = 'chopped/'
SHELL_ESCAPE_CHARS = ['[', ']', '?', '!']

def escape_shell_string(string):
    return multi_replace(string, *tuple((ch, '[{}]'.format(ch)) for ch in SHELL_ESCAPE_CHARS))

def find_matching_file_name(partial_track_name):
    escaped_track_name = escape_shell_string(partial_track_name)
    for file in os.listdir(ORIG_FILE_PATH):
        if fnmatch(file, '*{}*'.format(escaped_track_name)):
            return file
    raise Exception("'{}' not found in {}".format(escaped_track_name, ORIG_FILE_PATH))

# %%
"""
ffmpeg splitter working example
"""

import subprocess

def ffmpeg_formatted_ms(total_ms):
    return formatted_ms(total_ms, '00:{min}:{sec}.{ms}')

def ffmpeg_output_file_name(file_name):
    file_name_parts = file_name.rsplit('.', 1)
    return ''.join([file_name_parts[0], ' chopped', '.', file_name_parts[1]])

def ffmpeg_time_params(start_ms=None, stop_ms=None):
    start_ms = start_ms or 0
    formatted_start = ffmpeg_formatted_ms(start_ms)
    if stop_ms:
        formatted_duration = ffmpeg_formatted_ms(stop_ms - start_ms)
    else:
        formatted_duration = None
    return formatted_start, formatted_duration

def ffmpeg_param_list(in_file, out_file, formatted_start, formatted_duration=None):
    param_list = [
        'ffmpeg',
        '-i',
        in_file,
        '-vn',
        '-acodec',
        'copy',
        '-ss',
        formatted_start
    ]
    if formatted_duration:
        param_list += [
            '-t',
            formatted_duration
        ]
    param_list += [
        out_file
    ]
    return param_list

tracks = get_example_tracks()
process_results = []
for track in tracks:
    formatted_start, formatted_duration = ffmpeg_time_params(track['start_time'], track['stop_time'])
    file_name = find_matching_file_name(track['name'])
    full_file_path = '{}/{}'.format(ORIG_FILE_PATH, file_name)
    output_file_path = create_file_path(ORIG_FILE_PATH, CHOPPED_REL_FILE_PATH, ffmpeg_output_file_name(file_name))
    param_list = ffmpeg_param_list(full_file_path, output_file_path, formatted_start, formatted_duration)
    #print(' '.join(param_list))
    process_results.append(subprocess.run(param_list, stdout=subprocess.PIPE))

print(dir(process_results[0]))
print('')
for res in process_results:
    print(' '.join(res.args))
    print('    returncode: {}'.format(res.returncode))
    print('    stdout: {}'.format(res.stdout))

# ffmpeg -i '.mp3' -acodec copy -ss 00:00:08 -t 00:04:04 '.mp3'
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'args', 'check_returncode', 'returncode', 'stderr', 'stdout']
#
# ffmpeg -i /home/gavin/Music/chop/9 Runaway [Explicit].mp3 -vn -acodec copy -ss 00:00:00.000 -t 00:05:47.000 /home/gavin/Music/chop/chopped/9 Runaway [Explicit] chopped.mp3
#     returncode: 0
#     stdout: b''
# ffmpeg -i /home/gavin/Music/chop/5 The Way You Move (feat. Sleepy Brown).mp3 -vn -acodec copy -ss 00:00:00.000 -t 00:03:50.000 /home/gavin/Music/chop/chopped/5 The Way You Move (feat. Sleepy Brown) chopped.mp3
#     returncode: 0
#     stdout: b''
# ffmpeg -i /home/gavin/Music/chop/13 Debra.mp3 -vn -acodec copy -ss 00:00:00.000 -t 00:05:32.000 /home/gavin/Music/chop/chopped/13 Debra chopped.mp3
#     returncode: 0
#     stdout: b''
# ffmpeg -i /home/gavin/Music/chop/7 Opening Up (- Ce soir on danse Interlude).m4a -vn -acodec copy -ss 00:00:00.000 -t 00:03:25.000 /home/gavin/Music/chop/chopped/7 Opening Up (- Ce soir on danse Interlude) chopped.m4a
#     returncode: 0
#     stdout: b''

# %%
"""
Serialize tracks with start/stop times to JSON
"""

SERIALIZED_TRACK_FILE_PATH = './data/start_stop_track_info.json'
SERIALIZE_KEYS = ['artist', 'album_artist', 'album', 'name', 'start_time', 'stop_time', 'total_time']

c = get_cursor('itunes.db')

def serialize_track(track):
    return filter_dict_keys(track, SERIALIZE_KEYS)

def serialize_start_stop_tracks():
    start_stop_time_tracks = c.execute("SELECT * FROM tracks WHERE start_time IS NOT NULL;")\
                              .fetchall()
    write_json_to_file(SERIALIZED_TRACK_FILE_PATH, [serialize_track(track) for track in start_stop_time_tracks])

# serialize_start_stop_tracks()

# %%
"""
Find tracks in MusicBee based on serialized start/stop track data
"""

TRACK_LENGTH_COMPARE_PRECISION = 0.98

def track_query(track):
    return """
        SELECT * FROM tracks WHERE (artist='{artist}' OR album_artist='{artist}')
        AND name='{name}' COLLATE NOCASE;
        """.format(
            **{'artist': escape_query_value(track['artist']), 'name': escape_query_value(track['name'])}
        )

def artist_all_track_query(track):
    return "SELECT * FROM tracks WHERE (artist='{artist}' OR album_artist='{artist}')".format(
        **{'artist': escape_query_value(track['artist'])}
    )

def find_missing_track_by_duration(cursor, track_to_find):
    artist_tracks = cursor.execute(artist_all_track_query(track_to_find)).fetchall()
    for artist_track in artist_tracks:
        track_lengths = (artist_track['total_time'], track_to_find['total_time'])
        if min(*track_lengths)/max(*track_lengths) >= TRACK_LENGTH_COMPARE_PRECISION:
            return artist_track
    return None


c = get_mb_cursor()
start_stop_tracks = load_json_from_file(SERIALIZED_TRACK_FILE_PATH)
start_stop_track_count = len(start_stop_tracks)

missing_tracks = []
found_tracks = []
for track in start_stop_tracks:
    matching_tracks = c.execute(track_query(track)).fetchall()
    if len(matching_tracks) > 1:
        raise Exception("Track [{} - {}] was found {} times.".format(track['artist'], track['name'], len(matching_tracks)))
    elif len(matching_tracks) == 0:
        missing_tracks.append(track)
    else:
        found_tracks.append(matching_tracks[0])
        
for missing_track in missing_tracks[:]:
    found_track = find_missing_track_by_duration(c, missing_track)
    if found_track:
        found_tracks.append(found_track)
        missing_tracks = list(filter(found_track.__eq__, missing_tracks))

found_tracks
# Out:
# [{'album': 'Enter the Wu-Tang - 36 Chambers',
#   'album_artist': None,
#   'artist': 'Wu-Tang Clan',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:27:13',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Wu-Tang%20Clan/Enter%20the%20Wu-Tang%20-%2036%20Chambers/03%20Clan%20In%20Da%20Front.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Clan In Da Front',
#   'origin': None,
#   'persistent_id': 'E014F6114D7ED6F',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6676567,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 273266,
#   'track_count': None,
#   'track_id': 17112,
#   'track_number': 3,
#   'track_type': 'File',
#   'year': 1993},
#  {'album': 'Dangerous',
#   'album_artist': 'Michael Jackson',
#   'artist': 'Michael Jackson',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2009-12-31 11:33:54',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Pop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Michael%20Jackson/Dangerous/8%20Black%20Or%20White.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Black Or White',
#   'origin': None,
#   'persistent_id': '4A94FC737D086209',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 4105497,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 255947,
#   'track_count': 14,
#   'track_id': 9731,
#   'track_number': 8,
#   'track_type': 'File',
#   'year': 1991},
#  {'album': 'Enter the Wu-Tang - 36 Chambers',
#   'album_artist': None,
#   'artist': 'Wu-Tang Clan',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:27:13',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Wu-Tang%20Clan/Enter%20the%20Wu-Tang%20-%2036%20Chambers/04%207th%20Chamber.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': '7th Chamber',
#   'origin': None,
#   'persistent_id': 'E014F6161D6800',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 8889657,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 365479,
#   'track_count': None,
#   'track_id': 17113,
#   'track_number': 4,
#   'track_type': 'File',
#   'year': 1993},
#  {'album': 'Revolver',
#   'album_artist': None,
#   'artist': 'The Beatles',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Lennon-McCartney',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2010-10-25 05:28:38',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'iTunes v7.6.2, QuickTime 7.4.5',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Pop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Beatles/Revolver/5%20Here,%20There%20And%20Everywhere.m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Here, There And Everywhere',
#   'origin': None,
#   'persistent_id': 'C4289B19BE26190B',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 2419940,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 146773,
#   'track_count': 14,
#   'track_id': 14055,
#   'track_number': 5,
#   'track_type': 'File',
#   'year': 1966},
#  {'album': "Don't Phunk With My Heart",
#   'album_artist': 'Black Eyed Peas',
#   'artist': 'Black Eyed Peas',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 208,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-11-17 03:44:35',
#   'date_modified': '2011-04-19 23:00:14',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.96',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rap/Hip Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': "file://localhost/D:/Users/Gavin/Music/_Misc/Black%20Eyed%20Peas/Don't%20Phunk%20With%20My%20Heart/1%20Don't%20Phunk%20With%20My%20Heart.mp3",
#   'lyricist': None,
#   'mood': None,
#   'name': "Don't Phunk With My Heart",
#   'origin': None,
#   'persistent_id': '45BD05D82B2C0D17',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6379125,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 244897,
#   'track_count': None,
#   'track_id': 18183,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 2005},
#  {'album': '(no album)',
#   'album_artist': None,
#   'artist': 'Lil B',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2014-03-29 15:26:13',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lavf54.3.100',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Lil%20B/(no%20album)/00%20I%20Cook.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'I Cook',
#   'origin': None,
#   'persistent_id': '981BC1457A140C13',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 5249838,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 326452,
#   'track_count': None,
#   'track_id': 8808,
#   'track_number': None,
#   'track_type': 'File',
#   'year': None},
#  {'album': '(no album)',
#   'album_artist': None,
#   'artist': 'The Kinks',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2015-07-22 05:05:21',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lavf54.3.100',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Kinks/(no%20album)/00%20You%20Really%20Got%20Me%20(Remaster).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'You Really Got Me (Remaster)',
#   'origin': None,
#   'persistent_id': 'C7F663E015FBF391',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 2219617,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 137377,
#   'track_count': None,
#   'track_id': 14722,
#   'track_number': None,
#   'track_type': 'File',
#   'year': None},
#  {'album': 'Christmas Hits',
#   'album_artist': None,
#   'artist': 'Snowman',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-12-16 04:11:04',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.96',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Snowman/Christmas%20Hits/27%20Walking%20In%20The%20Air.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Walking In The Air',
#   'origin': None,
#   'persistent_id': 'B994E80BC80FEAF2',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 5117979,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 213232,
#   'track_count': None,
#   'track_id': 13098,
#   'track_number': 27,
#   'track_type': 'File',
#   'year': 2005},
#  {'album': 'Game Theory',
#   'album_artist': 'The Roots',
#   'artist': 'The Roots',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 216,
#   'bpm': None,
#   'comments': None,
#   'composer': 'J. Gray',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-06-26 19:57:48',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'FhG',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Roots/Game%20Theory/3%20Game%20Theory.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Game Theory',
#   'origin': None,
#   'persistent_id': 'A34CDC973C254C53',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6602479,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 241266,
#   'track_count': None,
#   'track_id': 15396,
#   'track_number': 3,
#   'track_type': 'File',
#   'year': 2006},
#  {'album': 'Another Level',
#   'album_artist': 'Blackstreet',
#   'artist': 'Blackstreet',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 256,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Chauncey Hannibal/Karen Anderson/Roosevelt Harrell/Teddy Riley',
#   'conductor': None,
#   'date_added': '2015-11-17 03:52:21',
#   'date_modified': '2011-02-06 00:46:36',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'R&B',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': "file://localhost/D:/Users/Gavin/Music/_Misc/Blackstreet/Another%20Level/7%20Don't%20Leave%20Me.mp3",
#   'lyricist': None,
#   'mood': None,
#   'name': "Don't Leave Me",
#   'origin': None,
#   'persistent_id': '39DE1FE3DC06B9D7',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': 'Interscope',
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 10145811,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 316912,
#   'track_count': None,
#   'track_id': 18190,
#   'track_number': 7,
#   'track_type': 'File',
#   'year': 1996},
#  {'album': 'Soul Survivor',
#   'album_artist': None,
#   'artist': 'Pete Rock',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 160,
#   'bpm': None,
#   'comments': '#1 Soul Brotha: [Hydro/aPC`98]',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2010-12-22 05:39:26',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Pete%20Rock/Soul%20Survivor/2%20Tru%20Master%20(feat.%20Inspectah%20Deck,%20Kurupt).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Tru Master (feat. Inspectah Deck, Kurupt)',
#   'origin': None,
#   'persistent_id': 'D14123A7CF590283',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 4858439,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 239369,
#   'track_count': 17,
#   'track_id': 11336,
#   'track_number': 2,
#   'track_type': 'File',
#   'year': 1998},
#  {'album': 'Phrenology',
#   'album_artist': 'The Roots',
#   'artist': 'The Roots',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 256,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Grand Wizard',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-12-14 17:40:32',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'iTunes 10.3.1.55, QuickTime 7.6.9',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rap',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Roots/Phrenology/17%20Rhymes%20And%20Ammo-Thirsty%20(featuring%20Talib%20Kweli).m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Rhymes And Ammo/Thirsty (featuring Talib Kweli)',
#   'origin': None,
#   'persistent_id': '2F29544E9972B14A',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 15944311,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 479956,
#   'track_count': 18,
#   'track_id': 15460,
#   'track_number': 17,
#   'track_type': 'File',
#   'year': 2002},
#  {'album': 'The Mouse And The Mask',
#   'album_artist': None,
#   'artist': 'Dangerdoom',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 320,
#   'bpm': None,
#   'comments': 'http://mp3caprice.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-11-04 05:16:58',
#   'date_modified': '2014-08-20 02:03:28',
#   'disc_count': 2,
#   'disc_number': 2,
#   'encoder': 'Lame3.98',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'hip hop, electronica, experimental',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Dangerdoom/The%20Mouse%20And%20The%20Mask/02-Sofa%20King.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Sofa King (Original)',
#   'origin': None,
#   'persistent_id': 'F12F7CF3DFF25AF9',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 7584304,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 177217,
#   'track_count': None,
#   'track_id': 18106,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 2005},
#  {'album': 'Hand on the Torch',
#   'album_artist': 'Us3',
#   'artist': 'Us3',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 256,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Geoff Wilkinson/Herbie Hancock/Mel Simpson/Rahsaan Kelly',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2010-09-09 19:52:34',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rap & Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Us3/Hand%20on%20the%20Torch/1%20Cantaloop%20(Flip%20Fantasia).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Cantaloop (Flip Fantasia)',
#   'origin': None,
#   'persistent_id': '9969E54D5B7C1F3F',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': 'Capitol',
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 8933135,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 279024,
#   'track_count': None,
#   'track_id': 16672,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 1993},
#  {'album': 'Only Built 4 Cuban Linx',
#   'album_artist': None,
#   'artist': 'Raekwon',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:25:44',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Raekwon/Only%20Built%204%20Cuban%20Linx/16%20Wu-Gambinos.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Wu-Gambinos',
#   'origin': None,
#   'persistent_id': '97CDD3E33DBF5796',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 8229347,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 339565,
#   'track_count': 18,
#   'track_id': 12018,
#   'track_number': 16,
#   'track_type': 'File',
#   'year': 1995},
#  {'album': '(no album)',
#   'album_artist': None,
#   'artist': 'Nelly Furtado',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2010-02-26 07:57:24',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'iTunes v6.0.4.2, QuickTime 7.0.4',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': '(No Genre)',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Nelly%20Furtado/(no%20album)/1%20Promiscuous%20(feat.%20Timbaland).m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Promiscuous (feat. Timbaland)',
#   'origin': None,
#   'persistent_id': '1EB4E29DEB705666',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 3931155,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 244297,
#   'track_count': 3,
#   'track_id': 10554,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': None},
#  {'album': 'Let It Be',
#   'album_artist': None,
#   'artist': 'The Beatles',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 256,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Lennon And McCartney',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2012-04-25 03:32:58',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'iTunes 10.0.1.22, QuickTime 7.6.8',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rock',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Beatles/Let%20It%20Be/12%20Get%20Back.m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Get Back',
#   'origin': None,
#   'persistent_id': '8867BE88FCF6076D',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6589253,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 187152,
#   'track_count': 12,
#   'track_id': 14012,
#   'track_number': 12,
#   'track_type': 'File',
#   'year': 1970},
#  {'album': 'Love Movement',
#   'album_artist': 'Tribe Called Quest',
#   'artist': 'Tribe Called Quest',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:58:17',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'iTunes v4.6.0.15, QuickTime 6.5.1',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Alternative Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Tribe%20Called%20Quest/Love%20Movement/17%20Money%20Maker.m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Money Maker',
#   'origin': None,
#   'persistent_id': '66FE23DF74C13255',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 4131589,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 262570,
#   'track_count': 21,
#   'track_id': 16462,
#   'track_number': 17,
#   'track_type': 'File',
#   'year': 1998},
#  {'album': 'Hot Tracks 15th Ann. Disc 15',
#   'album_artist': None,
#   'artist': 'The Bucketheads',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': 'from ilya_kuryakin@usa.net',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2016-03-31 04:23:04',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Dance',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Bucketheads/Hot%20Tracks%2015th%20Ann.%20Disc%2015/00%20These%20Sounds%20Fall%20Into%20My%20Mind.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'These Sounds Fall Into My Mind',
#   'origin': None,
#   'persistent_id': 'C0C86E67B7AA3BC0',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6192134,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 386879,
#   'track_count': None,
#   'track_id': 14252,
#   'track_number': None,
#   'track_type': 'File',
#   'year': 1997},
#  {'album': 'Liquid Swords',
#   'album_artist': 'GZA_Genius',
#   'artist': 'GZA/Genius',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 256,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2015-10-15 12:15:03',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'iTunes 12.3.0.44',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop/Rap',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/GZA_Genius/Liquid%20Swords/07%204th%20Chamber.m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': '4th Chamber',
#   'origin': None,
#   'persistent_id': '4A5A12CE61736C2',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 9486040,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 276967,
#   'track_count': 18,
#   'track_id': 6588,
#   'track_number': 7,
#   'track_type': 'File',
#   'year': 1995},
#  {'album': '(no album)',
#   'album_artist': None,
#   'artist': 'Lil B',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2014-03-29 16:50:48',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lavf54.3.100',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Lil%20B/(no%20album)/00%20Hoes%20On%20My%20D%20(feat.%20Andy%20Milonakis).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Hoes On My D (feat. Andy Milonakis)',
#   'origin': None,
#   'persistent_id': '981BC145620F1960',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 3213001,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 199784,
#   'track_count': None,
#   'track_id': 8807,
#   'track_number': None,
#   'track_type': 'File',
#   'year': None},
#  {'album': 'Youth & Young Manhood',
#   'album_artist': 'Kings of Leon',
#   'artist': 'Kings of Leon',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Angelo, Caleb Followill & Nathan Followill',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2015-10-16 02:48:03',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'iTunes 8.0.2.20, QuickTime 7.5.5',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rock',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Kings%20of%20Leon/Youth%20&%20Young%20Manhood/13%20Talihina%20Sky%20(Hidden%20Track).m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Talihina Sky (Hidden Track)',
#   'origin': None,
#   'persistent_id': '6FFC5B5614EDEB1',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 11779624,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 728409,
#   'track_count': 13,
#   'track_id': 8485,
#   'track_number': 13,
#   'track_type': 'File',
#   'year': 2007},
#  {'album': 'Enter the Wu-Tang - 36 Chambers',
#   'album_artist': None,
#   'artist': 'Wu-Tang Clan',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:27:13',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Wu-Tang%20Clan/Enter%20the%20Wu-Tang%20-%2036%20Chambers/01%20Bring%20Da%20Ruckus.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Bring Da Ruckus',
#   'origin': None,
#   'persistent_id': 'E014F615C0EED58',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6136772,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 250775,
#   'track_count': None,
#   'track_id': 17110,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 1993},
#  {'album': 'Love Movement',
#   'album_artist': 'Tribe Called Quest',
#   'artist': 'Tribe Called Quest',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:58:16',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'iTunes v4.6.0.15, QuickTime 6.5.1',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Alternative Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Tribe%20Called%20Quest/Love%20Movement/1%20Start%20It%20Up.m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Start It Up',
#   'origin': None,
#   'persistent_id': '66FE23DFF3389857',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 3235948,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 198553,
#   'track_count': 21,
#   'track_id': 16454,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 1998},
#  {'album': 'Reasonable Doubt',
#   'album_artist': 'Jay-Z',
#   'artist': 'Jay-Z',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 320,
#   'bpm': None,
#   'comments': None,
#   'composer': 'S. Carter, M. Miller, J. Foster',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-04-27 19:09:02',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'iTunes v7.6.2',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': "file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Jay-Z/Reasonable%20Doubt/1%20Can't%20Knock%20The%20Hustle%20(feat.%20Mary%20J.%20Blige).mp3",
#   'lyricist': None,
#   'mood': None,
#   'name': "Can't Knock The Hustle (feat. Mary J. Blige)",
#   'origin': None,
#   'persistent_id': '4B42B3793F62850E',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 12764192,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 317204,
#   'track_count': 15,
#   'track_id': 7313,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 1996},
#  {'album': 'The Mouse And The Mask',
#   'album_artist': 'Dangerdoom',
#   'artist': 'Dangerdoom',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-11-04 05:16:58',
#   'date_modified': '2015-09-27 22:40:26',
#   'disc_count': 2,
#   'disc_number': 1,
#   'encoder': 'Lavf54.3.100',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Dangerdoom/The%20Mouse%20And%20The%20Mask/Dangerdoom%20-%20Sofa%20King%20(Alternate%20Beat).mp3.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Sofa King (Alternate Beat)',
#   'origin': None,
#   'persistent_id': 'F12F7CF3D2ECCE01',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 3340416,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 178364,
#   'track_count': None,
#   'track_id': 14537,
#   'track_number': 2,
#   'track_type': 'File',
#   'year': 2005},
#  {'album': 'Paper Trail (Deluxe Version)',
#   'album_artist': 'T.I.',
#   'artist': 'T.I.',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 256,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2009-01-15 04:21:42',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip Hop/Rap',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'AAC audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/T.I/Paper%20Trail%20(Deluxe%20Version)/5%20Live%20Your%20Life%20(feat.%20Rihanna).m4a',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Live Your Life (feat. Rihanna)',
#   'origin': None,
#   'persistent_id': '84F531E07C9C2E05',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 11278366,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 338918,
#   'track_count': None,
#   'track_id': 13521,
#   'track_number': 5,
#   'track_type': 'File',
#   'year': '2008-08-12T07:00:00Z'},
#  {'album': 'Timbaland Presents: Shock Value',
#   'album_artist': None,
#   'artist': 'Timbaland',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 320,
#   'bpm': None,
#   'comments': 'http://mp3caprice.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-11-04 05:17:33',
#   'date_modified': '2014-04-23 00:08:36',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.98',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'hip-hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Timbaland/Timbaland%20Presents-%20Shock%20Value/04-The%20Way%20I%20Are%20Feat%20Keri%20Hilson%20And%20DOE.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'The Way I Are Feat Keri Hilson & D.O.E.',
#   'origin': None,
#   'persistent_id': 'D1FA72F8F6543CB0',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 7432577,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 179359,
#   'track_count': None,
#   'track_id': 6997,
#   'track_number': 4,
#   'track_type': 'File',
#   'year': 2007},
#  {'album': 'Tical 2000: Judgement Day',
#   'album_artist': None,
#   'artist': 'Method Man',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:15:13',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Method%20Man/Tical%202000-%20Judgement%20Day/2%20Perfect%20World.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Perfect World',
#   'origin': None,
#   'persistent_id': '3397AD4CD288C6B8',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 3063448,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 180300,
#   'track_count': None,
#   'track_id': 9568,
#   'track_number': 2,
#   'track_type': 'File',
#   'year': 1998},
#  {'album': 'Enter the Wu-Tang - 36 Chambers',
#   'album_artist': None,
#   'artist': 'Wu-Tang Clan',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:27:13',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Wu-Tang%20Clan/Enter%20the%20Wu-Tang%20-%2036%20Chambers/05%20Can%20It%20Be%20All%20So%20Simple.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Can It Be All So Simple',
#   'origin': None,
#   'persistent_id': 'E014F61FDDFEE7E',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 10030070,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 412995,
#   'track_count': None,
#   'track_id': 17114,
#   'track_number': 5,
#   'track_type': 'File',
#   'year': 1993},
#  {'album': 'Gold',
#   'album_artist': None,
#   'artist': 'Marvin Gaye',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 320,
#   'bpm': None,
#   'comments': 'http://mp3caprice.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2015-07-11 22:54:50',
#   'disc_count': None,
#   'disc_number': 1,
#   'encoder': 'Lame3.98',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'soul, rhythm & blues',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Marvin%20Gaye/Gold/06%20How%20Sweet%20It%20Is%20(To%20Be%20Loved%20By%20You).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'How Sweet It Is (To Be Loved By You)',
#   'origin': None,
#   'persistent_id': '218F9A84B9822A97',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 7151325,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 178680,
#   'track_count': None,
#   'track_id': 9412,
#   'track_number': 6,
#   'track_type': 'File',
#   'year': 2006},
#  {'album': 'Watch The Throne',
#   'album_artist': 'Kanye West & Jay-Z',
#   'artist': 'Kanye West & Jay-Z',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 320,
#   'bpm': None,
#   'comments': 'www.NewAlbumReleases.net',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-08-13 22:43:46',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.98',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip Hop/Rap',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Kanye%20West%20&%20Jay-Z/Watch%20The%20Throne/13%20Illest%20Motherf--ker%20Alive.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Illest Motherf**ker Alive',
#   'origin': None,
#   'persistent_id': 'F1C1E7417974A7EF',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 20342168,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 503382,
#   'track_count': 16,
#   'track_id': 8247,
#   'track_number': 13,
#   'track_type': 'File',
#   'year': None},
#  {'album': 'Life After Death',
#   'album_artist': 'The Notorious B.I.G.',
#   'artist': 'The Notorious B.I.G.',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 154,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-01-23 21:09:58',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'Lame3.90',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip-Hop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Notorious%20B.I.G/Life%20After%20Death/4%20Kick%20In%20The%20Door%20(feat.%20The%20Madd%20Rapper).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Kick In The Door (feat. The Madd Rapper)',
#   'origin': None,
#   'persistent_id': '4719BFD5B0A1884F',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 5590794,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 286981,
#   'track_count': 12,
#   'track_id': 15010,
#   'track_number': 4,
#   'track_type': 'File',
#   'year': 1997},
#  {'album': 'Faith',
#   'album_artist': 'George Michael',
#   'artist': 'George Michael',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': 'George Michael',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2007-02-17 23:45:12',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rock',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/George%20Michael/Faith/1%20Faith.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Faith',
#   'origin': None,
#   'persistent_id': 'BD44B074F148617',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': 'Columbia',
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 3137572,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 195919,
#   'track_count': None,
#   'track_id': 5942,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 1987},
#  {'album': 'Genius - The Ultimate Ray Charles Collection',
#   'album_artist': 'Ray Charles',
#   'artist': 'Ray Charles',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 229,
#   'bpm': None,
#   'comments': 'Amazon.com Song ID: 210558418',
#   'composer': 'Ray Charles',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2009-11-27 08:07:24',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'R&B',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Ray%20Charles/Genius%20-%20The%20Ultimate%20Ray%20Charles%20Collection/16%20Hallelujah%20I%20Love%20Her%20So.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Hallelujah I Love Her So',
#   'origin': None,
#   'persistent_id': '6E6FCE981F39CC4E',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 5352237,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 183954,
#   'track_count': 21,
#   'track_id': 12138,
#   'track_number': 16,
#   'track_type': 'File',
#   'year': 2009},
#  {'album': '(no album)',
#   'album_artist': None,
#   'artist': 'Rob Base & DJ EZ Rock',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 128,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2010-02-26 07:56:36',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': None,
#   'episode_date': None,
#   'episode_description': None,
#   'genre': '(No Genre)',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Rob%20Base%20&%20DJ%20EZ%20Rock/(no%20album)/00%20It%20Takes%20Two.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'It Takes Two',
#   'origin': None,
#   'persistent_id': 'E36CCD1B2FB1C5B5',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 4815181,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 300303,
#   'track_count': None,
#   'track_id': 12411,
#   'track_number': None,
#   'track_type': 'File',
#   'year': None},
#  {'album': 'The Best of Flock of Seagulls',
#   'album_artist': 'A Flock of Seagulls',
#   'artist': 'Flock Of Seagulls',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 320,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-03-04 04:03:46',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.98',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'New Wave',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Flock%20Of%20Seagulls/The%20Best%20of%20Flock%20of%20Seagulls/01%20I%20Ran%20(So%20Far%20Away).MP3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'I Ran (So Far Away)',
#   'origin': None,
#   'persistent_id': 'CA8B3DE9E0C40022',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 12307767,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 306288,
#   'track_count': None,
#   'track_id': 5502,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 1991},
#  {'album': 'Freedom Writers',
#   'album_artist': None,
#   'artist': 'Montell Jordan',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 219,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2012-02-10 07:53:22',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.90',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
# ...
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Dangerdoom/The%20Mouse%20And%20The%20Mask/12-Vats%20of%20Urine.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Vats of Urine',
#   'origin': None,
#   'persistent_id': 'F12F7CF371075978',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 4817422,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 108045,
#   'track_count': None,
#   'track_id': 7000,
#   'track_number': 12,
#   'track_type': 'File',
#   'year': 2005},
#  {'album': '(no album)',
#   'album_artist': None,
#   'artist': 'E-40 & Too $hort',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 251,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2014-10-02 17:49:04',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.98',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/E-40%20&%20Too%20$hort/(no%20album)/00%20Slide%20Through%20(feat.%20Tyga).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Slide Through (feat. Tyga)',
#   'origin': None,
#   'persistent_id': '719A7E3FEB6FB586',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6361883,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 201586,
#   'track_count': None,
#   'track_id': 4666,
#   'track_number': None,
#   'track_type': 'File',
#   'year': '11/6/2012'},
#  {'album': 'More Fish',
#   'album_artist': None,
#   'artist': 'Ghostface Killah',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-22 04:10:49',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Ghostface%20Killah/More%20Fish/1%20Ghost%20Is%20Back.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Ghost Is Back',
#   'origin': None,
#   'persistent_id': 'AB14B8509FAEF4F9',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 7797701,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 304561,
#   'track_count': None,
#   'track_id': 6032,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 2006},
#  {'album': 'Is This It',
#   'album_artist': 'The Strokes',
#   'artist': 'The Strokes',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 241,
#   'bpm': None,
#   'comments': 'Amazon.com Song ID: 203889435',
#   'composer': 'Julian Casablancas',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2009-12-30 09:50:48',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rock',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Strokes/Is%20This%20It/7%20Last%20Nite.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Last Nite',
#   'origin': None,
#   'persistent_id': 'D49DDDA6410D8644',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6015406,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 197120,
#   'track_count': 11,
#   'track_id': 15600,
#   'track_number': 7,
#   'track_type': 'File',
#   'year': 2001},
#  {'album': 'Ironman',
#   'album_artist': None,
#   'artist': 'Ghostface Killah',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 160,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Coles/Diggs',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2012-12-03 06:13:10',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'iTunes v7.0.2.16',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip Hop/Rap',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Ghostface%20Killah/Ironman/2%20Wildflower.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Wildflower',
#   'origin': None,
#   'persistent_id': 'D8DE8716434EE848',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 4724715,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 206628,
#   'track_count': 17,
#   'track_id': 6024,
#   'track_number': 2,
#   'track_type': 'File',
#   'year': 1996},
#  {'album': 'Mos Def & Talib Kweli Are Black Star',
#   'album_artist': 'Black Star',
#   'artist': 'Black Star',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 188,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-04-19 23:18:14',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'FhG',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rock',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Black%20Star/Mos%20Def%20&%20Talib%20Kweli%20Are%20Black%20Star/6%20Brown%20Skin%20Lady.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Brown Skin Lady',
#   'origin': None,
#   'persistent_id': '65C96087DBDE0EB8',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 8294006,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 346749,
#   'track_count': None,
#   'track_id': 2276,
#   'track_number': 6,
#   'track_type': 'File',
#   'year': 2002},
#  {'album': 'Surfer Rosa (Remastered)',
#   'album_artist': 'The Pixies',
#   'artist': 'The Pixies',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 191,
#   'bpm': None,
#   'comments': None,
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-01-08 23:12:42',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'Lame3.96',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Alternative',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Pixies/Surfer%20Rosa%20(Remastered)/12%20I%E2%80%99m%20Amazed%20(Remastered).mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'I’m Amazed (Remastered)',
#   'origin': None,
#   'persistent_id': 'DD577C447196A590',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 2566276,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 105325,
#   'track_count': None,
#   'track_id': 15141,
#   'track_number': 12,
#   'track_type': 'File',
#   'year': 1988},
#  {'album': 'Hot Fuss',
#   'album_artist': 'The Killers',
#   'artist': 'The Killers',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 320,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2012-05-16 00:59:02',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.98',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Killers/Hot%20Fuss/1%20Jenny%20Was%20a%20Friend%20of%20Mine.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Jenny Was a Friend of Mine',
#   'origin': None,
#   'persistent_id': 'D95001151687B34B',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 9809240,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 244218,
#   'track_count': 12,
#   'track_id': 14670,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 2004},
#  {'album': 'Ironman',
#   'album_artist': None,
#   'artist': 'Ghostface Killah',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 160,
#   'bpm': None,
#   'comments': None,
#   'composer': 'Coles/Diggs/Hawkins/Woods',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2012-12-03 06:13:13',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'iTunes v7.0.2.16',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Hip Hop/Rap',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Ghostface%20Killah/Ironman/13%20Black%20Jesus.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Black Jesus',
#   'origin': None,
#   'persistent_id': 'D8DE8716283BE234',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6141091,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 277446,
#   'track_count': 17,
#   'track_id': 6020,
#   'track_number': 13,
#   'track_type': 'File',
#   'year': 1996},
#  {'album': 'Only Built 4 Cuban Linx',
#   'album_artist': None,
#   'artist': 'Raekwon',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 192,
#   'bpm': None,
#   'comments': 'www.legalsounds.com',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2013-03-03 22:25:44',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': None,
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Raekwon/Only%20Built%204%20Cuban%20Linx/3%20Knowledge%20God.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Knowledge God',
#   'origin': None,
#   'persistent_id': '97CDD3E3A370E9AF',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6430659,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 264620,
#   'track_count': 18,
#   'track_id': 12022,
#   'track_number': 3,
#   'track_type': 'File',
#   'year': 1995},
#  {'album': 'Super Hits',
#   'album_artist': 'The Romantics',
#   'artist': 'The Romantics',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 239,
#   'bpm': None,
#   'comments': 'Amazon.com Song ID: 203899452',
#   'composer': 'Wally Palmar',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-03-02 05:31:14',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Pop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Romantics/Super%20Hits/1%20What%20I%20Like%20About%20You.MP3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'What I Like About You',
#   'origin': None,
#   'persistent_id': '73EA7446877DC7',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': 'Sony',
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 5348093,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 177345,
#   'track_count': None,
#   'track_id': 15361,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 1998},
#  {'album': 'Life After Death',
#   'album_artist': None,
#   'artist': 'The Notorious B.I.G.',
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 222,
#   'bpm': None,
#   'comments': 'OSM_INT #distribution Efnet',
#   'composer': None,
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2011-01-23 21:07:12',
#   'disc_count': None,
#   'disc_number': None,
#   'encoder': 'Lame3.90',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Rap',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/The%20Notorious%20B.I.G/Life%20After%20Death/04%20Going%20Back%20to%20Cali.mp3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'Going Back to Cali',
#   'origin': None,
#   'persistent_id': '4719BFD535AA34EA',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': None,
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 8612193,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 307487,
#   'track_count': 12,
#   'track_id': 15006,
#   'track_number': 4,
#   'track_type': 'File',
#   'year': 1997},
#  {'album': 'Evolution: The Hits',
#   'album_artist': 'Dead Or Alive',
#   'artist': "80's One Hit Wonders",
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 244,
#   'bpm': None,
#   'comments': 'Amazon.com Song ID: 203904628',
#   'composer': 'Michael Percy',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2016-05-10 03:32:53',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Pop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Dead%20Or%20Alive/Evolution-%20The%20Hits/1%20You%20Spin%20Me%20Round%20(Like%20A%20Record).MP3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'You Spin Me Round (Like A Record) (Dead Or Alive)',
#   'origin': None,
#   'persistent_id': '24714036D9D4F04B',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': 'Epic/Legacy',
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6067820,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 197198,
#   'track_count': 18,
#   'track_id': 4224,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 2003}]

# %%
##################################

# %%
c = get_cursor('musicbee.db')
# column_names(c, 'tracks')
c.execute("SELECT * FROM tracks WHERE (artist='Dead Or Alive' OR album_artist='Dead Or Alive') COLLATE NOCASE;").fetchall()

# c = get_cursor('itunes.db')
# column_names(c, 'tracks')

# c = get_cursor('musicbee.db')
# # column_names(c, 'tracks')
# c.execute("SELECT * FROM tracks WHERE name LIKE '%The Way You Move%';").fetchall()

# start_time_tracks = c.execute("SELECT * FROM tracks WHERE start_time IS NOT NULL;")\
#         .fetchall()
# [(track['artist'], track['name'], track['start_time'])
#     for track in start_stop_tracks[10:20]]
# Out:
# [{'album': 'Evolution: The Hits',
#   'album_artist': 'Dead Or Alive',
#   'artist': "80's One Hit Wonders",
#   'artist1': None,
#   'artist2': None,
#   'bit_rate': 244,
#   'bpm': None,
#   'comments': 'Amazon.com Song ID: 203904628',
#   'composer': 'Michael Percy',
#   'conductor': None,
#   'date_added': '2015-10-21 02:01:26',
#   'date_modified': '2016-05-10 03:32:53',
#   'disc_count': 1,
#   'disc_number': 1,
#   'encoder': 'Lame3.97',
#   'episode_date': None,
#   'episode_description': None,
#   'genre': 'Pop',
#   'genre1': None,
#   'genre2': None,
#   'grouping': None,
#   'itunes_compilation': None,
#   'keywords': None,
#   'kind': 'MPEG audio file',
#   'location': 'file://localhost/D:/Users/Gavin/Music/Clip%20MicroSD/Dead%20Or%20Alive/Evolution-%20The%20Hits/1%20You%20Spin%20Me%20Round%20(Like%20A%20Record).MP3',
#   'lyricist': None,
#   'mood': None,
#   'name': 'You Spin Me Round (Like A Record) (Dead Or Alive)',
#   'origin': None,
#   'persistent_id': '24714036D9D4F04B',
#   'play_count': None,
#   'play_date_utc': None,
#   'publisher': 'Epic/Legacy',
#   'rating': None,
#   'relative_volume_adjustment': None,
#   'rememberplaybackposition': None,
#   'sample_rate': 44100,
#   'size': 6067820,
#   'sort_album_artist': None,
#   'sort_artist': None,
#   'tempo': None,
#   'total_time': 197198,
#   'track_count': 18,
#   'track_id': 4224,
#   'track_number': 1,
#   'track_type': 'File',
#   'year': 2003}]

# %%
# import urllib
# urllib.parse.unquote('07%20Opening%20Up%20(-%20Ce%20soir%20on%20danse%20In.m4a') 

# time=332000
# ms = time % 1000
# time -= ms
# time /= 1000
# seconds = time % 60
# time -= seconds
# time /= 60
# minutes = time
# (minutes, seconds, ms)

# import os, fnmatch
# for file in os.listdir(ORIG_FILE_PATH):
#     #print(file)
#     if fnmatch.fnmatch(file, '*Runaway [[]Ex*'):
#         print(file)

# SHELL_ESCAPE_CHARS = ['[', ']', '?', '!']
# def escape_shell_string(string):
#     for c in SHELL_ESCAPE_CHARS:
#         string = string.replace(c, '\{}'.format(c))
#     return string
# escape_shell_string('Runaway [Explicit]')

# import re
# def multi_replacer(*key_values):
#     replace_dict = dict(key_values)
#     replacement_function = lambda match: replace_dict[match.group(0)]
#     pattern = re.compile("|".join([re.escape(k) for k, v in key_values]), re.M)
#     return lambda string: pattern.sub(replacement_function, string)
# def multi_replace(string, *key_values):
#     return multi_replacer(*key_values)(string)
# replacements = ('[', '[[]'), (']', '[]]')
# multi_replace('Runaway [Explicit]', *replacements)
# Out:
# 4

# %%
"""
mp3splt working example
Fails on m4a
"""

# import subprocess

# MP3SPLT_DEFAULT_START = '0.0.0'
# MP3SPLT_DEFAULT_STOP = 'EOF'

# def mp3splt_output_file_name(file_name):
#     file_name_parts = file_name.rsplit('.', 1)
#     return ''.join([file_name_parts[0], ' chopped'])

# tracks = get_example_tracks()
# process_results = []
# for track in tracks:
#     start_arg, stop_arg = \
#         dot_formatted_ms(track['start_time']), dot_formatted_ms(track['stop_time'])
#     start_arg = start_arg or MP3SPLT_DEFAULT_START
#     stop_arg = stop_arg or MP3SPLT_DEFAULT_STOP
#     file_name = find_matching_file_name(track['name'])
#     full_file_path = '{}/{}'.format(ORIG_FILE_PATH, file_name)
#     mp3splt_param_list = [
#         'mp3splt',
#         full_file_path,
#         start_arg,
#         stop_arg,
#         '-o',
#         CHOPPED_REL_FILE_PATH + mp3splt_output_file_name(file_name)
#     ]
#     process_results.append(subprocess.run(mp3splt_param_list, stdout=subprocess.PIPE))

# process_results
